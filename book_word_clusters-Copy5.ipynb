# %%
import time
import pandas as pd
from wikiapi import WikiApi
wiki = WikiApi()
import re
from gensim.models import Word2Vec
#import word2vec
from scipy.spatial.distance import cosine
import numpy as np
import heapq
import string

# %%
def remove_punctuation(s):
    exclude = set(string.punctuation)
    s = ''.join(ch for ch in s if ch not in exclude)
    return s
#TODO: fix this or dont use
def get_longword(s, n):
    s = re.split(' ', s)
    return heapq.nlargest(n, s, key=len)

def get_rarewrd(s):
    s = re.split(' ', s)
    freqs = [words.count(x) for x in s]
    dd= [i for i,x in enumerate(freqs) if x == min(freqs)]
    return [s[dd[0]]]

#TODO: make this work with one word/period
def get_avg_vec(words):
	try:
		words = re.split(' ', words)
	except:
		pass
	nwords = 0
	featureVec = np.zeros((num_features,))#,dtype="float32")
	for word in words:
		if word in index2word_set:
			nwords = nwords + 1.
			featureVec = np.add(featureVec,model[word])
	if nwords > 0:
		featureVec = np.divide(featureVec,nwords)
	return featureVec

def get_tvec(row):
    if row['correctAnswer'] == 'A':
        a = row['aavec']
        return a
    elif row['correctAnswer'] == 'B':
        a = row['bavec']
        return a
    elif row['correctAnswer'] == 'C':
        a = row['cavec']
        return a
    elif row['correctAnswer'] == 'D':
        a = row['davec']
        return a
    
def run_through_theta(v):
    return v.dot(theta.as_matrix())

def get_winner_from_avecs(row):
	try:	
		dists = []
		for col in row['answerA':'answerD']:
		#TODO: if 'not' in words: 1-avec
			avec = get_avg_vec(col)
			#if 'not' in re.split(' ',col):
			#	avec = 1-avec
			#	print('NOT')
			#why nan errors?
			if sum(np.isfinite(avec)) < 300:
				print('avec')
				print(avec)
			if  sum(np.isfinite(row['pvec'])) < 300:
				print('pvec')
				print(row['pvec'])
			dist = cosine(avec, row['pvec'])
			dists.append(dist)
		m = np.nanmin(dists)
		best = [i for i, j in enumerate(dists) if j == m]
		if best == [0]:
			return 'A'
		if best == [1]:

			return 'B'
		if best == [2]:
			return 'C'
		if best == [3]:
			return 'D'
		else:
			print('returning C becuase no best cosine')
			print(len(best))
			print(dists)
			print(m)
			return 'C'
	except:
		print('some error, returning C')
		return 'C'
    
    
    
    
def word_clusters(row):
    if str(row.id)[-2:] == '01':
        print(row.id)
        print('\n\n\n\n')
    print(row.correctAnswer)
    try:
        keywds = row.keyword

        word_pos = {}
        for keyw in keywds:
            ls = [i for i,x in enumerate(words) if x == keyw]
            #print(ls)
            word_pos[keyw] = ls

        spots = []
        for key1 in keywds:
            print(key1)
            matches = {}
            for z in word_pos[key1]:
                dists=[]
                for key_ in keywds:
                    d= abs(min(word_pos[key_], key=lambda x:abs(x-z))-z)
                    dists.append(d)
                #print(z)
                #print(dists)
                dists.remove(max(dists))
                matches[z] = sum(dists)

            zzz= [k for k, v in matches.items() if v ==min(matches.values())]
            spots.append(zzz[0])
        print(spots)
        answers = row['akeyword':'dkeyword']
        kkk = []
        for answer in answers:
            print(answer[0])
            waka = 0
            for x in spots:
                wd = words[x-1000:x+1000]
                ct = wd.count(answer[0])
                waka = (waka + ct)#/(words.count(answer[0])/2)    #trying to skew for 
            kkk.append(waka)
        mx = max(kkk)
        print(kkk)
        best = [i for i, j in enumerate(kkk) if j == mx]
        if best == [0]:
            return 'A'
        if best == [1]:
            return 'B'
        if best == [2]:
            return 'C'
        if best == [3]:
            return 'D'
        else:
            print('returning C becuase no max')
            return 'C'
    except:
        print('returning C becuase of BIG PROBLEM')
        return 'C'

# %% [raw]
# start = time.time()
# model = Word2Vec.load_word2vec_format('/Users/liamconnell/Downloads/GoogleNews-vectors-negative300.bin', binary = True)
# lap1 = time.time()
# print('data gathered: %s' % (lap1 - start))

# %% [raw]
# index2word_set = set(model.index2word)
# num_features = 300

# %%
data  = pd.read_csv('../input/training_set.tsv', '\t')
#data  = pd.read_csv('../input/validation_set.tsv', '\t')

# %%
file = open('../input/Concepts.txt', 'r')
words = list(file.read().split())
words = [word.strip(string.punctuation) for word in words]

# %%
data.question = data.question.apply(remove_punctuation)
data.answerA = data.answerA.apply(remove_punctuation)
data.answerB = data.answerB.apply(remove_punctuation)
data.answerC = data.answerC.apply(remove_punctuation)
data.answerD = data.answerD.apply(remove_punctuation)

# %%
data['keyword'] =data['question'].apply(get_longword, args = (4,))

#I get to choose this
#data['qvec'] = data.keyword.apply(get_avg_vec)

# %%
data['akeyword'] =data['answerA'].apply(get_rarewrd)
data['bkeyword'] =data['answerB'].apply(get_rarewrd)
data['ckeyword'] =data['answerC'].apply(get_rarewrd)
data['dkeyword'] =data['answerD'].apply(get_rarewrd)

# %% [raw]
# #data['qvec'] = data.question.apply(get_avg_vec)
# data['akeyword'] =data['answerA'].apply(get_longword, args = (1,))
# data['bkeyword'] =data['answerB'].apply(get_longword, args = (1,))
# data['ckeyword'] =data['answerC'].apply(get_longword, args = (1,))
# data['dkeyword'] =data['answerD'].apply(get_longword, args = (1,))

# %%
data['guess'] = data.apply(word_clusters, axis = 1)
# Out:
# 100001
#
#
#
#
#
# C
# organization
# respiration
# coordinate
# functions
# [968935, 969021, 92838, 968842]
# tissue
# organ
# level
# cellular
# [7, 21, 10, 0]
# C
# describes
# behavior
# example
# learned
# [1157988, 79019, 79015, 79018]
# smelling
# barking
# command
# digging
# [0, 0, 0, 0]
# returning C becuase no max
# D
# combined
# nucleus
# release
# process
# [31785, 1326800, 1326815, 1326794]
# conversion
# reaction
# fission
# fusion
# [0, 30, 69, 54]
# B
# distinction
# epidemic
# pandemic
# between
# [826710, 788843, 788846, 788841]
# symptoms
# geographical
# infected
# spreads
# [6, 0, 12, 9]
# B
# different
# which
# orbit
# comet
# [1446058, 1446080, 1446055, 56710]
# comet
# comet
# comet
# predictable
# [1, 1, 1, 0]
# returning C becuase no max
# B
# concerning
# hydrogen
# electron
# accurate
# [1513400, 1142023, 1142012, 1141970]
# particles
# relative
# present
# charges
# [51, 0, 0, 3]
# A
# substance
# splashed
# student
# should
# [791269, 461909, 1126366, 461978]
# water
# vinegar
# salt
# formaldehyde
# [43, 0, 0, 0]
# A
# source
# energy
# water
# cycle
# [660778, 660777, 396596, 295670]
# Sun
# fuels
# clouds
# ocean
# [12, 4, 5, 6]
# D
# greatest
# movement
# through
# effect
# [1328182, 977295, 977306, 977287]
# tension
# friction
# density
# gravity
# [0, 0, 0, 0]
# returning C becuase no max
# C
# nonvolcanic
# returning C becuase of BIG PROBLEM
# D
# temperature
# temperature
# becoming
# average
# [335889, 335889, 476618, 335888]
# decrease
# sugar
# decrease
# flow
# [0, 0, 0, 0]
# returning C becuase no max
# D
# explanation
# ecology
# Which
# best
# [371047, 1857, 371122, 371120]
# nonliving
# study
# renewal
# interactions
# [1, 21, 0, 1]
# A
# insecticide
# illustrated
# resistance
# pesticide
# [101920, 207452, 101977, 101971]
# selection
# selective
# aerobic
# sexual
# [3, 0, 0, 0]
# C
# individually
# Researchers
# statements
# efficient
# [1100838, 1102812, 222848, 1104547]
# published
# costs
# researchers
# researchers
# [1, 0, 0, 0]
# B
# Achromatopsia
# returning C becuase of BIG PROBLEM
# B
# elements
# compound
# organic
# likely
# [932801, 932799, 932798, 365543]
# helium
# hydrogen
# mercury
# tin
# [0, 27, 0, 0]
# C
# scientists
# statement
# describes
# principle
# [2264, 1529434, 909154, 2248]
# Solid
# deflect
# seismic
# seismic
# [0, 0, 0, 0]
# returning C becuase no max
# A
# percentages
# percentages
# illustrate
# scientist
# [1259997, 1259997, 1261645, 1208247]
# bar
# scatterplot
# circle
# pictograph
# [0, 0, 0, 0]
# returning C becuase no max
# B
# limitation
# returning C becuase of BIG PROBLEM
# B
# investigated
# percentage
# population
# obtained
# [38250, 1038193, 1040552, 1038772]
# table
# pie
# bar
# graph
# [0, 0, 0, 0]
# returning C becuase no max
# C
# measurement
# collecting
# launched
# describe
# [233604, 461756, 233322, 233761]
# meters
# kilometers
# astronomical
# years
# [6, 3, 0, 0]
# C
# structure
# nutrients
# cellular
# allows
# [1014271, 120540, 1014253, 1014277]
# mitochondrion
# nucleus
# membrane
# chloroplast
# [0, 21, 18, 0]
# C
# establish
# territory
# behavior
# animals
# [1105779, 83657, 83646, 83649]
# migrates
# trail
# howls
# honeybee
# [0, 0, 0, 0]
# returning C becuase no max
# D
# function
# perform
# primary
# spinal
# [1074342, 1074339, 939726, 871393]
# enabling
# transporting
# producing
# coordinate
# [0, 0, 0, 0]
# returning C becuase no max
# A
# statement
# describes
# liquid
# sample
# [914066, 914258, 544626, 914503]
# retain
# keeps
# greatly
# Its
# [0, 0, 0, 0]
# returning C becuase no max
# B
# population
# condition
# ecosystem
# collapse
# [927476, 926017, 926240, 332616]
# thickness
# decline
# diseases
# pest
# [0, 0, 0, 0]
# returning C becuase no max
# D
# heterotrophs
# contains
# kingdoms
# contain
# [990620, 990452, 61569, 990428]
# Protists
# Animals
# Fungi
# Animals
# [11, 0, 2, 0]
# D
# produces
# through
# passes
# retina
# [1512270, 1512276, 1512275, 872274]
# smaller
# larger
# upright
# inverse
# [3, 0, 0, 0]
# B
# effectiveness
# researchers
# scientists
# medication
# [1100527, 1329983, 1101897, 1100772]
# email
# journal
# brochures
# Internet
# [0, 0, 0, 0]
# returning C becuase no max
# B
# scientific
# scientists
# discover
# universe
# [1145938, 908832, 1145944, 1423950]
# analysis
# experiment
# conclusion
# observation
# [3, 19, 0, 12]
# B
# investigate
# scientists
# beneficial
# scientists
# [444581, 444580, 44962, 444580]
# topics
# perspectives
# topics
# access
# [0, 0, 0, 0]
# returning C becuase no max
# B
# contributor
# pollution
# greatest
# United
# [219703, 219756, 219702, 345635]
# factories
# automobiles
# power
# burning
# [0, 0, 1, 3]
# B
# stratosphere
# important
# organisms
# content
# [317959, 667089, 9295, 317955]
# Ozone
# Ozone
# Ozone
# Ozone
# [10, 10, 10, 10]
# returning C becuase no max
# A
# interacting
# environment
# decomposers
# ecosystems
# [195051, 796849, 798223, 796836]
# dead
# survival
# preventing
# consumers
# [23, 0, 0, 0]
# A
# environments
# Populations
# changing
# respond
# [219220, 219366, 219253, 817290]
# adaptation
# competition
# ecological
# extinction
# [1, 0, 3, 27]
# D
# determines
# sequence
# protein
# number
# [964268, 964263, 964266, 538965]
# properties
# shape
# size
# All
# [0, 6, 9, 0]
# C
# generations
# returning C becuase of BIG PROBLEM
# B
# establishes
# describes
# community
# retreats
# [1089173, 768529, 769819, 769405]
# disturbance
# succession
# weathering
# stabilization
# [2, 51, 0, 0]
# B
# experiencing
# returning C becuase of BIG PROBLEM
# D
# concentration
# environment
# pesticides
# conclusion
# [994270, 405697, 405689, 993777]
# pesticides
# picked
# nesting
# contaminated
# [2, 0, 0, 0]
# D
# circulatory
# function
# system
# What
# [145359, 145356, 145360, 145361]
# secrete
# digest
# hormones
# materials
# [0, 0, 0, 0]
# returning C becuase no max
# A
# organism
# lowest
# Which
# level
# [677476, 497018, 497158, 677463]
# autotroph
# heterotroph
# carnivore
# omnivore
# [0, 0, 0, 0]
# returning C becuase no max
# A
# mechanisms
# atmosphere
# transfer
# transfer
# [1535842, 320206, 320215, 320215]
# conduction
# retention
# convection
# conduction
# [24, 0, 24, 24]
# returning C becuase no max
# A
# sedimentary
# sedimentary
# scientist
# statement
# [263286, 263286, 263403, 775098]
# buried
# sedimentary
# examine
# Sedimentary
# [0, 17, 0, 5]
# C
# statement
# describes
# nature
# Which
# [909152, 909154, 909162, 465672]
# fastest
# Sound
# Sound
# Sound
# [0, 0, 0, 0]
# returning C becuase no max
# C
# gastroenterologist
# returning C becuase of BIG PROBLEM
# A
# wildflowers
# returning C becuase of BIG PROBLEM
# A
# following
# returning C becuase of BIG PROBLEM
# A
# wavelengths
# increasing
# following
# according
# [1164202, 1163454, 1296043, 1296017]
# xrays
# xrays
# xrays
# xrays
# [0, 0, 0, 0]
# returning C becuase no max
# B
# protostar
# pressure
# hydrogen
# reached
# [1522466, 1522452, 1522513, 1288606]
# giant
# star
# super
# hole
# [22, 101, 0, 8]
# C
# contaminated
# situation
# vacation
# hillside
# [1252536, 335535, 337217, 329914]
# cabin
# bottled
# buckets
# barrels
# [0, 0, 0, 0]
# returning C becuase no max
# B
# biodegradable
# returning C becuase of BIG PROBLEM
# A
# external
# located
# scrotum
# because
# [896300, 896371, 896387, 812275]
# production
# scrotum
# epididymus
# exiting
# [2, 9, 0, 0]
# D
# following
# Which
# three
# major
# [1375043, 1375040, 1375031, 1349150]
# intrusive
# granite
# pumice
# metamorphic
# [0, 0, 0, 0]
# returning C becuase no max
# B
# determines
# complete
# phases
# takes
# [564676, 248816, 248610, 564754]
# rotation
# revolution
# rotation
# revolution
# [0, 1, 0, 1]
# returning C becuase no max
# D
# Arabidopsis
# observation
# conclusion
# unusually
# [918076, 914966, 911955, 725607]
# codes
# heredity
# Traits
# Traits
# [1, 1, 3, 3]
# returning C becuase no max
# A
# resource
# natural
# Which
# about
# [223517, 223511, 754146, 223509]
# stewardship
# exhausted
# stewardship
# exhausted
# [0, 0, 0, 0]
# returning C becuase no max
# A
# experiences
# statement
# response
# explains
# [703709, 915029, 1528549, 1528384]
# contracts
# valves
# Breathing
# letting
# [0, 0, 0, 0]
# returning C becuase no max
# B
# experiment
# scientific
# practices
# discovery
# [1114919, 1114918, 5307, 1114825]
# reporting
# successfully
# records
# willing
# [0, 0, 0, 0]
# returning C becuase no max
# C
# explanation
# detergent
# particles
# suspended
# [793419, 444860, 794187, 794915]
# organic
# dissolving
# dense
# faster
# [10, 0, 0, 0]
# A
# immediately
# ability
# likely
# water
# [1277606, 756847, 798797, 798792]
# rigid
# absorb
# release
# again
# [1, 8, 6, 0]
# D
# offspring
# increases
# opossum
# female
# [82021, 82006, 854656, 82082]
# mature
# reliable
# maternal
# likelihood
# [5, 0, 0, 0]
# D
# investigating
# experimental
# different
# following
# [717059, 718806, 492096, 718788]
# trials
# considering
# balls
# testable
# [0, 0, 4, 0]
# D
# environment
# located
# likely
# change
# [973254, 1141402, 973248, 973259]
# releasing
# nonnative
# adding
# returning
# [0, 0, 0, 0]
# returning C becuase no max
# D
# organism
# involves
# process
# moving
# [110340, 110333, 973358, 973370]
# digestive
# nervous
# excretory
# respiratory
# [0, 0, 0, 0]
# returning C becuase no max
# B
# cardiovascular
# indicator
# following
# pressure
# [879366, 1297746, 879335, 879342]
# cmHg
# mmHg
# gcm3
# gmm3
# [0, 0, 0, 0]
# returning C becuase no max
# A
# characteristic
# likely
# object
# volume
# [841212, 586403, 586414, 586418]
# density
# low
# viscosity
# high
# [12, 4, 0, 0]
# A
# considered
# expanding
# freezing
# wedging
# [1241720, 1241620, 1239768, 349205]
# weathering
# transportation
# deposition
# lithification
# [50, 0, 3, 0]
# C
# development
# vegetation
# ecosystem
# Clearing
# [218147, 201730, 201842, 201931]
# wildlife
# competition
# erosion
# runoff
# [0, 0, 1, 0]
# C
# relationship
# acceleration
# relationship
# acceleration
# [1360130, 1360132, 1360130, 1360132]
# increase
# change
# decrease
# direction
# [4, 24, 4, 20]
# C
# offspring
# offspring
# explains
# flowers
# [1037921, 1037921, 36097, 1037924]
# experienced
# resulted
# exhibited
# pinkcolored
# [0, 0, 0, 0]
# returning C becuase no max
# B
# organisms
# evolving
# earliest
# organism
# [105221, 105254, 65465, 105226]
# multi
# celled
# fungi
# viruses
# [0, 0, 51, 0]
# A
# technology
# technology
# positive
# negative
# [449061, 449061, 449065, 449067]
# jobs
# production
# alternate
# destruction
# [4, 4, 0, 0]
# returning C becuase no max
# C
# requires
# Lifting
# weight
# with
# [1446906, 1446900, 158192, 1446941]
# flexion
# extension
# flexion
# flexion
# [0, 0, 0, 0]
# returning C becuase no max
# B
# particles
# neutral
# numbers
# charge
# [493472, 1391319, 1391321, 1391314]
# neutrons
# protons
# neutrons
# neutrons
# [2, 23, 2, 2]
# A
# Extinction
# extinction
# organisms
# variation
# [218104, 218101, 218095, 784416]
# asexually
# size
# producers
# sexually
# [0, 3, 0, 0]
# D
# directly
# protect
# disease
# Which
# [212899, 175318, 175240, 175132]
# heart
# kidney
# pancreas
# skin
# [16, 6, 18, 19]
# D
# directions
# opposite
# unequal
# forces
# [1449348, 1449347, 323231, 1449345]
# absorb
# immediate
# continue
# larger
# [0, 0, 0, 0]
# returning C becuase no max
# B
# chemically
# chlorine
# formed
# sodium
# [1122671, 1122658, 1189448, 1189451]
# element
# compound
# electron
# neutron
# [40, 50, 58, 0]
# C
# lightbulbs
# electrons
# Electric
# circuits
# [511422, 1491552, 1491538, 1491507]
# closed
# series
# open
# parallel
# [6, 0, 0, 12]
# D
# Scientists
# conducting
# scientists
# throughout
# [666626, 666611, 666662, 1424803]
# records
# pharmacies
# paid
# validity
# [0, 0, 0, 1]
# A
# carbohydrate
# functions
# similar
# lipid
# [962723, 962716, 128410, 962721]
# Both
# replicated
# activation
# dissolve
# [1, 0, 0, 0]
# B
# accelerate
# falling
# causes
# object
# [1433549, 574080, 1433546, 1433545]
# inertia
# gravity
# initial
# initial
# [6, 78, 3, 3]
# B
# statement
# correctly
# describes
# reactants
# [909152, 1216674, 1216532, 1216603]
# substances
# present
# separates
# written
# [12, 2, 3, 24]
# A
# following
# explosion
# organisms
# greatest
# [743346, 743343, 743364, 931229]
# Explosion
# Explosion
# CretaceousTertiary
# Asteroid
# [0, 0, 0, 0]
# returning C becuase no max
# B
# reactions
# involved
# chemical
# Which
# [1110708, 522626, 522627, 21519]
# nucleus
# negativelycharged
# neutrallycharged
# positivelycharged
# [0, 0, 0, 0]
# returning C becuase no max
# C
# following
# formation
# compound
# result
# [514027, 1190734, 514023, 1277353]
# coloring
# filings
# combining
# melting
# [0, 4, 0, 0]
# C
# accelerated
# direction
# Constant
# measure
# [1527989, 1285520, 1285639, 1285533]
# distance
# speed
# velocity
# direction
# [1, 30, 7, 8]
# D
# hydrangea
# returning C becuase of BIG PROBLEM
# A
# mitochondria
# function
# plant
# cells
# [686977, 686975, 688926, 688927]
# release
# attach
# energyrich
# assemble
# [0, 0, 0, 0]
# returning C becuase no max
# B
# specifically
# organelle
# organisms
# vacuoles
# [994987, 683336, 683310, 965687]
# tissues
# cells
# organ
# organs
# [2, 188, 0, 0]
# D
# difference
# elements
# between
# element
# [8218, 1183993, 8219, 8214]
# ions
# protons
# electrons
# neutrons
# [30, 21, 12, 9]
# D
# dramatic
# history
# change
# Which
# [744901, 465721, 744946, 744974]
# blizzard
# flood
# earthquake
# asteroid
# [0, 0, 0, 3]
# A
# molecules
# messages
# membrane
# special
# [961560, 19522, 961563, 961562]
# endocrine
# lymphatic
# excretory
# integumentary
# [0, 0, 0, 0]
# returning C becuase no max
# D
# reactants
# invisible
# following
# products
# [521794, 686823, 521806, 521803]
# rearranged
# produced
# absorbed
# produced
# [6, 10, 3, 10]
# returning C becuase no max
# A
# competition
# important
# species
# during
# [198937, 198946, 198943, 928167]
# fittest
# juvenile
# communication
# speeds
# [0, 0, 0, 0]
# returning C becuase no max
# B
# environments
# extensive
# following
# blooming
# [816448, 816257, 816953, 75633]
# prairie
# desert
# coniferous
# deciduous
# [0, 0, 0, 0]
# returning C becuase no max
# D
# evidence
# returning C becuase of BIG PROBLEM
# D
# investigations
# scientific
# providing
# detailed
# [2455, 2126, 665034, 1125]
# reports
# published
# professionalism
# replicated
# [0, 1, 0, 0]
# B
# California
# returning C becuase of BIG PROBLEM
# 100101
#
#
#
#
#
# B
# direction
# completed
# Margaret
# circular
# [1519622, 1520006, 68273, 1519567]
# north
# south
# east
# west
# [6, 6, 0, 0]
# returning C becuase no max
# D
# Paleontologists
# returning C becuase of BIG PROBLEM
# A
# different
# Students
# learning
# students
# [1398374, 923696, 923714, 1398442]
# tossing
# shaking
# throwing
# toy
# [0, 0, 0, 0]
# returning C becuase no max
# B
# classified
# statements
# organisms
# different
# [746733, 915722, 746734, 780998]
# genus
# phylum
# kingdoms
# members
# [8, 0, 4, 0]
# B
# respiration
# necessary
# cellular
# oxygen
# [23457, 23240, 23474, 703295]
# dioxide
# glucose
# water
# ATP
# [52, 57, 18, 119]
# C
# geologist
# evidence
# tectonic
# support
# [748489, 749287, 290342, 749289]
# fossils
# coastlines
# spreading
# appearances
# [18, 0, 0, 0]
# B
# organelles
# functions
# athletes
# athletes
# [698571, 168938, 168726, 168726]
# Golgi
# mitochondrion
# ribosome
# nucleus
# [0, 0, 0, 0]
# returning C becuase no max
# B
# flattened
# elongated
# spheres
# rounded
# [1529712, 1533351, 1519676, 1534249]
# irregular
# elliptical
# spiral
# eclipse
# [0, 2, 0, 2]
# returning C becuase no max
# D
# forests
# likely
# affect
# does
# [218970, 175138, 175097, 175126]
# Top
# deeper
# Animals
# Trees
# [0, 0, 0, 0]
# returning C becuase no max
# C
# freshwater
# describes
# remaining
# movement
# [88291, 87984, 301443, 87830]
# aquifers
# swamps
# caps
# rivers
# [1, 0, 4, 3]
# C
# HardyWeinberg
# returning C becuase of BIG PROBLEM
# B
# experiences
# rainforest
# statement
# tropical
# [202690, 202707, 201251, 202899]
# bedrock
# fewer
# soileating
# reaching
# [0, 0, 0, 0]
# returning C becuase no max
# B
# illustrated
# stimulates
# platelets
# platelets
# [878511, 876172, 879566, 879566]
# feedback
# feedback
# feedback
# stimulation
# [30, 30, 30, 1]
# returning C becuase no max
# C
# following
# choices
# contain
# element
# [1186991, 887058, 1186948, 1186954]
# rod
# salt
# lily
# distilled
# [0, 0, 0, 0]
# returning C becuase no max
# C
# whiteflowered
# returning C becuase of BIG PROBLEM
# C
# participating
# experiment
# experiment
# alcohol
# [463928, 913830, 913830, 913833]
# jacket
# goggles
# tie
# apron
# [0, 0, 0, 0]
# returning C becuase no max
# A
# happens
# rotated
# likely
# crops
# [355026, 1025153, 354863, 354952]
# depleted
# fertility
# porous
# erodes
# [0, 0, 0, 13]
# D
# coordinates
# functions
# controls
# nervous
# [870901, 871272, 871270, 871263]
# throughout
# spinal
# spinal
# responding
# [8, 48, 48, 0]
# returning C becuase no max
# C
# wellrounded
# returning C becuase of BIG PROBLEM
# A
# transformed
# returning C becuase of BIG PROBLEM
# C
# responsible
# processes
# primarily
# creation
# [272011, 1328630, 1328612, 272007]
# runoff
# evaporation
# runoff
# condensation
# [0, 0, 0, 0]
# returning C becuase no max
# B
# insecticides
# populations
# eradicate
# explains
# [44855, 794507, 791212, 793575]
# Cockroach
# Cockroach
# Cockroach
# Cockroach
# [0, 0, 0, 0]
# returning C becuase no max
# D
# temperatures
# temperatures
# temperatures
# contributes
# [341505, 341505, 341505, 344554]
# Foliage
# rainforest
# rainforest
# Cloud
# [0, 9, 9, 0]
# returning C becuase no max
# D
# Ribosomes
# following
# processes
# sites
# [782313, 880830, 880863, 782315]
# nucleotide
# transcription
# lipid
# translation
# [0, 0, 0, 0]
# returning C becuase no max
# A
# Chlorophyll
# chloroplast
# chlorophyll
# scientists
# [20859, 993562, 993576, 993548]
# plant
# animal
# human
# bacteria
# [52, 8, 0, 23]
# C
# occurs
# returning C becuase of BIG PROBLEM
# D
# development
# atmospheric
# development
# hypothesis
# [1520574, 1234978, 1520574, 1520602]
# Galileo
# critique
# providing
# inspiring
# [24, 0, 0, 0]
# A
# drought
# likely
# affect
# plants
# [779025, 662285, 662287, 779068]
# shorter
# thicker
# variety
# brighter
# [0, 0, 0, 0]
# returning C becuase no max
# B
# variations
# variations
# organisms
# favorable
# [749164, 749164, 562114, 749163]
# disruptive
# selection
# sexual
# directional
# [0, 69, 0, 0]
# C
# atmosphere
# change
# clouds
# Which
# [318360, 318349, 318353, 1010375]
# evaporation
# freezing
# condensation
# melting
# [0, 0, 0, 0]
# returning C becuase no max
# D
# relationship
# between
# exists
# fleas
# [955665, 209748, 955666, 200368]
# commensalism
# gradualism
# mutualism
# parasitism
# [4, 0, 4, 3]
# returning C becuase no max
# B
# volcanic
# boundary
# island
# found
# [270536, 270521, 270510, 270201]
# oceanicoceanic
# oceanicoceanic
# continentaloceanic
# continentaloceanic
# [0, 0, 0, 0]
# returning C becuase no max
# C
# information
# synthesis
# ribosome
# protein
# [378825, 1351225, 1351222, 1351224]
# rRNA
# tRNA
# mRNA
# DNA
# [0, 18, 21, 73]
# B
# complementary
# adenine
# What
# base
# [676019, 1062467, 676017, 676020]
# cytosine
# thymine
# guanine
# uracil
# [21, 25, 21, 7]
# A
# meteoroid
# meteorite
# becomes
# when
# [418238, 418201, 250806, 418385]
# impacts
# encounters
# orbit
# burn
# [3, 0, 17, 0]
# D
# substances
# physically
# substances
# classified
# [468336, 889941, 468336, 468368]
# atom
# mixture
# element
# compound
# [0, 84, 3, 20]
# C
# investigating
# chemical
# reaction
# products
# [3863, 1216431, 521731, 1216430]
# separately
# mixture
# separately
# reactants
# [0, 0, 0, 66]
# D
# statements
# following
# thermal
# energy
# [1375044, 606008, 606004, 606005]
# cup
# milk
# cup
# cup
# [0, 0, 0, 0]
# returning C becuase no max
# B
# electricity
# technology
# electrical
# economical
# [1139929, 1140310, 1140258, 405038]
# fuel
# reactor
# collector
# turbine
# [5, 0, 0, 7]
# D
# vocalization
# returning C becuase of BIG PROBLEM
# C
# measurement
# granite
# volume
# Which
# [922140, 349072, 1128046, 1128051]
# thermometer
# ruler
# graduated
# triple
# [0, 2, 2, 0]
# returning C becuase no max
# C
# barometer
# measure
# used
# is
# [1228856, 945710, 1232917, 1149202]
# wind
# temperature
# atmospheric
# humidity
# [0, 32, 28, 0]
# C
# includes
# positive
# nucleus
# atomic
# [504870, 1515359, 1515364, 1515363]
# evenly
# sites
# concentrated
# positioned
# [3, 0, 6, 0]
# C
# conclusion
# phenomenon
# inherited
# together
# [1017451, 1017196, 1074935, 1017630]
# controlled
# Both
# adjacent
# trait
# [0, 1, 1, 0]
# returning C becuase no max
# C
# activities
# contribute
# extinction
# species
# [211919, 221535, 211901, 211900]
# hunting
# destruction
# restoration
# nonnative
# [1, 0, 0, 0]
# D
# experiments
# returning C becuase of BIG PROBLEM
# C
# contractions
# responsible
# following
# chambers
# [872581, 872496, 872681, 877197]
# atrium
# atrium
# ventricle
# ventricle
# [5, 5, 3, 3]
# returning C becuase no max
# D
# formation
# substance
# involves
# chemical
# [1312294, 992412, 992400, 992405]
# gasoline
# pepper
# tea
# rusting
# [0, 0, 0, 3]
# D
# yellow
# banana
# banana
# appear
# [1473035, 1473036, 1473036, 1473037]
# blue
# yellow
# green
# black
# [28, 8, 8, 12]
# B
# sedimentary
# observed
# resulted
# layers
# [376627, 1522200, 376127, 376803]
# cooling
# crustal
# deposition
# carbonate
# [0, 0, 0, 0]
# returning C becuase no max
# A
# scientific
# experiment
# describes
# benefit
# [462346, 462459, 462326, 665268]
# Variables
# subjects
# explained
# variables
# [0, 0, 0, 0]
# returning C becuase no max
# C
# transport
# property
# narrow
# upward
# [943451, 943260, 943350, 334097]
# vapor
# boiling
# cohesion
# net
# [1, 15, 12, 0]
# A
# temperatures
# property
# survive
# allows
# [476013, 475941, 765106, 765162]
# insulating
# sinks
# slows
# Ice
# [0, 0, 2, 2]
# returning C becuase no max
# C
# compressive
# formation
# Himalayan
# Mountains
# [275048, 274163, 293206, 293215]
# spreading
# strikeslip
# colliding
# spots
# [0, 0, 0, 0]
# returning C becuase no max
# A
# population
# contains
# consists
# region
# [779747, 1145880, 482953, 482945]
# halo
# spiral
# bulge
# clusters
# [0, 0, 0, 0]
# returning C becuase no max
# C
# marshmallows
# marshmallow
# marshmallow
# substance
# [1219010, 1219008, 1219008, 1219086]
# marshmallow
# oxygen
# carbon
# fire
# [12, 76, 28, 12]
# D
# susceptibility
# populations
# individual
# aggression
# [1062750, 1075573, 1062639, 822011]
# decrease
# stay
# shift
# increase
# [0, 1, 0, 1]
# returning C becuase no max
# B
# observations
# observations
# observation
# Students
# [910999, 910999, 911004, 1422797]
# feels
# ms
# nicer
# looks
# [0, 0, 0, 3]
# D
# communities
# succession
# natural
# likely
# [210860, 210587, 210568, 210875]
# bushes
# bushes
# bushes
# bushes
# [0, 0, 0, 0]
# returning C becuase no max
# D
# composite
# material
# Which
# these
# [290294, 1486585, 1124213, 1124215]
# window
# statue
# aluminum
# fiberglass
# [0, 0, 0, 0]
# returning C becuase no max
# D
# dispensers
# returning C becuase of BIG PROBLEM
# B
# experiments
# returning C becuase of BIG PROBLEM
# A
# Improvements
# technology
# farming
# likely
# [1100084, 772657, 772689, 773891]
# increase
# global
# promote
# daily
# [4, 1, 0, 0]
# B
# Hemisphere
# occurring
# Australia
# Northern
# [108160, 775297, 108178, 108159]
# fall
# winter
# spring
# summer
# [0, 0, 0, 1]
# B
# responsible
# generate
# universe
# released
# [1369019, 1414544, 1369033, 1369016]
# weak
# strong
# gravitational
# electromagnetic
# [0, 0, 27, 0]
# D
# describes
# orbiting
# objects
# Kuiper
# [241210, 241259, 241192, 425304]
# metallic
# rocky
# hot
# icy
# [0, 1, 0, 2]
# C
# mountainside
# returning C becuase of BIG PROBLEM
# C
# characteristic
# distinguishes
# viruses
# cells
# [954784, 793044, 954805, 954820]
# hereditary
# environments
# independent
# pressures
# [3, 1, 0, 0]
# C
# electricity
# following
# insulator
# against
# [1486603, 1486597, 1486601, 1319145]
# copper
# tubing
# tape
# foil
# [11, 0, 0, 0]
# D
# development
# nutritional
# nutrition
# describes
# [100432, 100808, 101149, 100226]
# ward
# nesting
# adequate
# mates
# [0, 0, 0, 0]
# returning C becuase no max
# C
# negativelycharged
# returning C becuase of BIG PROBLEM
# C
# Greenhouse
# atmosphere
# greenhouse
# surface
# [345122, 345121, 320981, 417158]
# nitrogen
# argon
# vapor
# oxygen
# [0, 0, 2, 0]
# C
# photosynthesis
# compounds
# chemical
# presence
# [993131, 58621, 58620, 999800]
# CO2
# O2
# CO2
# O2
# [0, 0, 0, 0]
# returning C becuase no max
# B
# collected
# returning C becuase of BIG PROBLEM
# A
# continuous
# hypothesis
# continues
# changing
# [1064046, 1063898, 1063987, 756174]
# layered
# atmospheric
# vast
# displacement
# [0, 0, 0, 0]
# returning C becuase no max
# B
# machines
# systems
# Simple
# reduce
# [1453011, 1453571, 1453024, 813357]
# twice
# output
# output
# output
# [6, 31, 31, 31]
# returning C becuase no max
# D
# digestion
# statement
# describes
# stomach
# [882993, 835113, 882836, 883103]
# function
# performs
# perform
# perform
# [1, 0, 0, 0]
# D
# following
# invention
# computers
# personal
# [772908, 772552, 449541, 772686]
# Internet
# keyboard
# wireless
# integrated
# [0, 0, 0, 0]
# returning C becuase no max
# D
# lightbulb
# direction
# different
# direction
# [663840, 1446059, 53397, 1446059]
# lightbulb
# lightbulb
# battery
# produced
# [3, 3, 0, 0]
# returning C becuase no max
# A
# investigators
# antibiotic
# represent
# clinical
# [918685, 42743, 41606, 42282]
# independent
# financially
# pharmaceutical
# funds
# [0, 0, 0, 0]
# returning C becuase no max
# D
# electricity
# returning C becuase of BIG PROBLEM
# B
# investigation
# geologist
# determine
# procedure
# [1424316, 47391, 1423253, 1423907]
# procedures
# improves
# wants
# prove
# [3, 1, 0, 0]
# A
# semipermeable
# Materials
# membrane
# utilized
# [981434, 1112859, 1106498, 1106234]
# diffusion
# oxidation
# respiration
# reproduction
# [0, 0, 1, 0]
# C
# straightening
# returning C becuase of BIG PROBLEM
# C
# observation
# conditions
# landforms
# produced
# [993821, 993536, 292935, 292180]
# tectonic
# tectonic
# tectonic
# tectonic
# [2, 2, 2, 2]
# returning C becuase no max
# D
# necessarily
# following
# substance
# substance
# [1311030, 1117633, 1117645, 1117645]
# physical
# temperature
# pressure
# All
# [27, 27, 3, 3]
# returning C becuase no max
# B
# characteristics
# returning C becuase of BIG PROBLEM
# B
# following
# Which
# helps
# orbit
# [1446016, 575315, 175013, 575308]
# friction
# gravity
# longitude
# latitude
# [0, 53, 0, 0]
# C
# components
# necessary
# Sperm
# and
# [69643, 20810, 181312, 20811]
# asexual
# budding
# sexual
# mitosis
# [0, 0, 1, 4]
# C
# whitetail
# returning C becuase of BIG PROBLEM
# A
# planetesimal
# returning C becuase of BIG PROBLEM
# C
# inherited
# trait
# An
#
# [57173, 57174, 1039636, 57175]
# determined
# multiple
# determined
# determined
# [0, 0, 0, 0]
# returning C becuase no max
# A
# radioactive
# Minerals
# elements
# contain
# [553321, 254564, 553322, 553317]
# igneous
# sedimentary
# layering
# weathering
# [0, 0, 0, 0]
# returning C becuase no max
# A
# different
# primarily
# composed
# contain
# [1120809, 1211209, 1120799, 10588]
# cellulose
# glucose
# bilayer
# chlorophyll
# [0, 0, 0, 0]
# returning C becuase no max
# D
# buildings
# following
# damage
# caused
# [283940, 885598, 334320, 334331]
# industrial
# burned
# exhaust
# radiation
# [2, 0, 0, 0]
# B
# poorly
# easier
# detect
# black
# [609315, 280972, 609333, 609572]
# refracts
# reflects
# reflects
# refracts
# [0, 0, 0, 0]
# returning C becuase no max
# C
# beings
# color
# human
# Eye
# [161891, 1041073, 1041108, 1041072]
# instinct
# acquired
# inherited
# environmentally
# [0, 0, 6, 0]
# C
# mathematical
# explanations
# conclusions
# scientist
# [1424092, 1424128, 2583, 2608]
# Ptolemy
# Aristotle
# Nicolas
# Dmitri
# [0, 0, 0, 0]
# returning C becuase no max
# C
# biogeochemical
# returning C becuase of BIG PROBLEM
# B
# transmitted
# structures
# signal
# muscle
# [869845, 133024, 132972, 133011]
# sensory
# interneurons
# neurons
# mechanoreceptor
# [3, 1, 17, 0]
# 100201
#
#
#
#
#
# A
# structure
# located
# which
# the
# [938117, 484966, 938118, 32351]
# Galaxy
# Andromeda
# Cats
# Horseshoe
# [0, 0, 0, 0]
# returning C becuase no max
# B
# function
# contains
# nucleus
# control
# [686454, 686450, 686457, 960441]
# cytoplasm
# material
# envelope
# membrane
# [50, 14, 35, 55]
# A
# explains
# object
# Which
# human
# [585263, 585349, 585358, 636971]
# detected
# infrared
# reflect
# detected
# [0, 0, 3, 0]
# A
# Astronomers
# planets
# closer
# Earth
# [230161, 415008, 575407, 575405]
# observing
# observing
# observing
# observing
# [0, 0, 0, 0]
# returning C becuase no max
# C
# uplifting
# Mountains
# geologic
# process
# [348266, 368657, 368567, 368492]
# glaciation
# flooding
# faulting
# erosion
# [0, 0, 0, 19]
# B
# calculating
# following
# density
# useful
# [1413898, 1413888, 1413951, 1312732]
# balance
# graduated
# graduated
# beaker
# [0, 0, 0, 9]
# D
# transverse
# particles
# through
# happens
# [1468049, 494961, 494965, 494958]
# Particles
# Particles
# Particles
# Particles
# [0, 0, 0, 0]
# returning C becuase no max
# B
# electromagnetic
# technology
# equipment
# spectrum
# [1413025, 326936, 1412957, 1413026]
# radio
# visible
# microwaves
# Xrays
# [0, 0, 0, 0]
# returning C becuase no max
# D
# sufficiently
# returning C becuase of BIG PROBLEM
# C
# greatest
# impact
# humans
# carbon
# [72470, 208878, 208868, 208881]
# clearcutting
# manufacturing
# burning
# agricultural
# [0, 0, 19, 0]
# A
# sedimentary
# sedimentary
# exposed
# fossils
# [259910, 259910, 274206, 259907]
# environments
# volcanic
# rates
# evaporation
# [6, 1, 0, 0]
# D
# manufacturer
# returning C becuase of BIG PROBLEM
# D
# Paleontologists
# paleontologists
# scientists
# determine
# [48911, 49422, 48903, 48905]
# examine
# library
# interview
# records
# [0, 0, 0, 0]
# returning C becuase no max
# B
# relationship
# relationship
# generations
# generations
# [48717, 48717, 48709, 48709]
# mutualistic
# mutualistic
# parasitic
# mutualistic
# [0, 0, 0, 0]
# returning C becuase no max
# C
# responding
# returning C becuase of BIG PROBLEM
# B
# mechanical
# shoulder
# similar
# device
# [1454301, 428779, 1454045, 1454415]
# sliding
# socket
# hinge
# antagonistic
# [0, 0, 0, 0]
# returning C becuase no max
# C
# individual
# returning C becuase of BIG PROBLEM
# A
# reactions
# generate
# objects
# created
# [1317419, 1317421, 1317428, 1155327]
# stars
# planets
# moons
# asteroids
# [0, 0, 0, 0]
# returning C becuase no max
# A
# identified
# element
# An
# is
# [540415, 932955, 1265392, 465778]
# protons
# atomic
# charge
# isotopes
# [11, 9, 8, 0]
# A
# concentrations
# temperatures
# temperatures
# Temperature
# [60966, 350995, 350995, 350987]
# Earths
# Earths
# Earths
# Earths
# [0, 0, 0, 0]
# returning C becuase no max
# B
# difference
# appearance
# asteroids
# causes
# [425960, 786684, 425824, 425968]
# revolve
# comets
# comets
# comets
# [0, 44, 44, 44]
# returning C becuase no max
# C
# relationships
# returning C becuase of BIG PROBLEM
# D
# ecosystem
# nitrogen
# bacteria
# reduced
# [784893, 784907, 784913, 1311178]
# nitrates
# decompose
# accumulate
# nitrogen
# [0, 0, 0, 4]
# A
# fertilizer
# fertilizer
# effective
# granular
# [912686, 912686, 913327, 301642]
# fertilizer
# neutralizes
# fertilizer
# fertilizer
# [9, 0, 9, 9]
# returning C becuase no max
# A
# biologists
# obtaining
# studying
# behavior
# [917853, 831401, 1274, 917902]
# interpretations
# reject
# expectations
# journal
# [0, 0, 0, 0]
# returning C becuase no max
# B
# Scientists
# discovered
# wavelength
# discovery
# [485967, 485977, 639799, 486042]
# drink
# healthier
# healthier
# stronger
# [0, 0, 0, 0]
# returning C becuase no max
# D
# substance
# different
# substance
# chemistry
# [464037, 467042, 464037, 1129260]
# boiling
# bubbling
# floated
# evaporating
# [17, 0, 0, 2]
# A
# convergent
# geological
# difference
# different
# [271365, 273585, 261477, 273665]
# trench
# trench
# rift
# Under
# [2, 2, 3, 3]
# returning C becuase no max
# D
# element
# common
# What
# most
# [466067, 465830, 335419, 1186383]
# helium
# oxygen
# nitrogen
# hydrogen
# [6, 25, 9, 29]
# B
# abnormal
# division
# disease
# result
# [1081741, 1081754, 1076507, 1081748]
# AIDS
# cancer
# pox
# cold
# [0, 64, 0, 0]
# A
# cockroaches
# centimeters
# cockroaches
# Paleozoic
# [927327, 901804, 927327, 855852]
# environmental
# effects
# predators
# destroyed
# [0, 2, 5, 0]
# B
# theoretical
# returning C becuase of BIG PROBLEM
# A
# population
# dissolved
# contains
# affected
# [52472, 547057, 547056, 547017]
# ponds
# oceans
# lakes
# streams
# [0, 0, 0, 0]
# returning C becuase no max
# A
# endosymbiotic
# endosymbiotic
# organelles
# eukaryotic
# [793435, 793435, 742130, 742143]
# Eukaryote
# Eukaryote
# Eukaryote
# Eukaryote
# [0, 0, 0, 0]
# returning C becuase no max
# C
# describes
# proton
# Which
# best
# [1419504, 1511260, 1419499, 1419503]
# negligible
# negatively
# positively
# negatively
# [0, 0, 0, 0]
# returning C becuase no max
# B
# chemically
# combine
# product
# carbon
# [466775, 1124492, 1124498, 1122374]
# plus
# plus
# equal
# less
# [0, 0, 1, 2]
# C
# Antarctica
# returning C becuase of BIG PROBLEM
# B
# investigation
# researchers
# conducting
# scientific
# [665857, 665969, 666611, 914653]
# formulating
# formulating
# analyzing
# experimental
# [0, 0, 1, 1]
# returning C becuase no max
# A
# responsible
# returning C becuase of BIG PROBLEM
# A
# experienced
# deposits
# geologic
# process
# [399138, 49438, 49437, 399327]
# intrusion
# transport
# weathering
# compaction
# [0, 0, 0, 0]
# returning C becuase no max
# C
# statementDespite
# returning C becuase of BIG PROBLEM
# A
# substances
# different
# property
# dissolve
# [466100, 466099, 465498, 464168]
# polar
# contains
# melting
# density
# [0, 13, 3, 41]
# A
# transport
# process
# Storms
# energy
# [975065, 975066, 1249628, 974525]
# Sun
# oceans
# Earth
# clouds
# [0, 0, 0, 0]
# returning C becuase no max
# D
# exploring
# students
# students
# realized
# [1369662, 1163405, 1163405, 1164243]
# accumulation
# diffraction
# refraction
# reflection
# [0, 0, 0, 0]
# returning C becuase no max
# B
# function
# ability
# release
# amounts
# [967819, 967815, 157003, 1327448]
# exchanging
# parts
# absorbing
# sending
# [0, 0, 0, 0]
# returning C becuase no max
# B
# consisting
# organisms
# molecules
# contain
# [1183706, 674424, 1183725, 674428]
# triple
# variety
# diamonds
# sizes
# [0, 0, 0, 0]
# returning C becuase no max
# C
# process
# clouds
# Which
# occur
# [22994, 1523704, 23071, 23042]
# erosion
# conduction
# condensation
# precipitation
# [0, 0, 0, 0]
# returning C becuase no max
# A
# experimental
# statement
# mistake
# design
# [1133291, 1529434, 1133038, 1133400]
# control
# pot
# received
# Too
# [3, 0, 0, 6]
# B
# composed
# element
# mostly
# Which
# [1182212, 1182248, 1523605, 1182308]
# helium
# hydrogen
# iron
# radiation
# [7, 10, 19, 1]
# A
# statement
# describes
# Which
# best
# [862600, 1419504, 1419499, 1419503]
# Atoms
# Atoms
# subatomic
# packets
# [0, 0, 6, 0]
# B
# Continental
# continents
# describes
# continent
# [267732, 267705, 375822, 267717]
# Fossils
# Fossils
# civilizations
# Patterns
# [3, 3, 0, 0]
# returning C becuase no max
# A
# difference
# structure
# organisms
# describes
# [959609, 925051, 925065, 925064]
# adult
# simpler
# adult
# adult
# [3, 0, 3, 3]
# returning C becuase no max
# A
# properties
# Magnesium
# Magnesium
# reactive
# [505047, 1219614, 1219614, 1219618]
# lithium
# silver
# chlorine
# nonreactive
# [4, 19, 7, 0]
# C
# experiment
# scientists
# scientist
# conducts
# [588, 589, 930, 1060902]
# variables
# Equipment
# Results
# wellknown
# [0, 0, 1, 0]
# C
# conditions
# proteins
# required
# produce
# [996758, 992672, 996760, 996740]
# synthesizing
# altering
# expressing
# mutating
# [0, 0, 0, 0]
# returning C becuase no max
# C
# supporting
# scientists
# continents
# following
# [1424055, 264985, 264991, 743346]
# Gravitational
# differentiated
# redistribute
# disperses
# [0, 0, 0, 0]
# returning C becuase no max
# A
# calculate
# useful
# volume
# would
# [457702, 1260302, 457704, 457701]
# ruler
# scale
# voltmeter
# thermometer
# [0, 0, 0, 0]
# returning C becuase no max
# C
# influenza
# returning C becuase of BIG PROBLEM
# D
# mechanical
# converted
# brother
# seconds
# [1397549, 1397517, 1527082, 1397728]
# heats
# swing
# swing
# thermal
# [3, 0, 0, 3]
# returning C becuase no max
# B
# recognizes
# realizes
# expected
# heavier
# [738025, 1055400, 1059958, 1063586]
# circulatory
# nervous
# respiratory
# skeletal
# [0, 0, 0, 0]
# returning C becuase no max
# B
# Fossils
# younger
# layers
# layers
# [49107, 274388, 274386, 274386]
# petrified
# faulting
# igneous
# fossils
# [0, 0, 0, 14]
# D
# arrangement
# continents
# current
# formed
# [1165620, 373691, 373670, 373674]
# craters
# Earths
# widespread
# geological
# [0, 0, 0, 0]
# returning C becuase no max
# B
# contributes
# rotational
# hurricane
# develops
# [344554, 422645, 347358, 352986]
# Stream
# Coriolis
# humidity
# highpressure
# [1, 0, 2, 0]
# A
# communicating
# investigation
# experimental
# researchers
# [914656, 665857, 912444, 665882]
# verify
# modify
# variables
# variables
# [1, 0, 20, 20]
# returning C becuase no max
# B
# adaptation
# predators
# example
# defense
# [199700, 199712, 199679, 78613]
# giraffes
# deers
# oily
# fishs
# [0, 0, 0, 0]
# returning C becuase no max
# A
# respiration
# respiration
# cellular
# cellular
# [741888, 741888, 541703, 541703]
# CO2
# CO2
# CO2
# CO2
# [0, 0, 0, 0]
# returning C becuase no max
# A
# catastrophically
# eruptions
# volcanic
# asteroid
# [291272, 376467, 376466, 376419]
# finegrained
# explosion
# Earths
# warmed
# [0, 1, 0, 0]
# C
# appears
# because
# larger
# other
# [635209, 635220, 1482028, 1529954]
# yellow
# high
# distance
# composition
# [12, 4, 13, 0]
# A
# Ultraviolet
# Ultraviolet
# Ultraviolet
# Ultraviolet
# [319921, 319921, 319921, 319921]
# shorter
# spectrum
# band
# barely
# [4, 16, 0, 0]
# C
# likely
# spread
# people
# bottle
# [188118, 188129, 188115, 796458]
# asthma
# malaria
# strep
# hay
# [0, 7, 0, 0]
# C
# fourlegged
# returning C becuase of BIG PROBLEM
# B
# continental
# continental
# continents
# tectonics
# [330622, 330622, 330619, 269200]
# zones
# shared
# Congress
# teachers
# [2, 0, 0, 0]
# D
# characteristics
# reproduce
# asexually
# resulting
# [66989, 66658, 66659, 66645]
# organization
# organelles
# lesser
# combination
# [0, 0, 0, 0]
# returning C becuase no max
# D
# electricgasolinehybrid
# returning C becuase of BIG PROBLEM
# D
# projected
# through
# screen
# called
# [1483834, 1483827, 1483837, 636199]
# refraction
# virtual
# reflection
# real
# [1, 9, 31, 7]
# B
# extinctions
# conditions
# likely
# fossil
# [775569, 756172, 756386, 756295]
# competition
# cooling
# beneficial
# increased
# [0, 0, 0, 0]
# returning C becuase no max
# D
# radiant
# energy
# called
# range
# [319290, 319784, 319786, 319782]
# spectrum
# audio
# spectrum
# spectrum
# [16, 0, 16, 16]
# returning C becuase no max
# D
# direction
# continue
# moving
# tennis
# [1501958, 1444553, 1501950, 1372295]
# downward
# frictional
# frictional
# acted
# [0, 0, 0, 0]
# returning C becuase no max
# C
# balanced
# acting
# object
# motion
# [569342, 1367845, 579232, 1367849]
# pushes
# decrease
# change
# increase
# [9, 0, 11, 1]
# C
# information
# organizing
# potential
# estimate
# [1124734, 1124317, 1125186, 649934]
# box
# shelf
# shelf
# shelf
# [0, 0, 0, 0]
# returning C becuase no max
# C
# represented
# preventing
# geographic
# mountain
# [235261, 778254, 235368, 234604]
# susceptible
# infertile
# droughtresistant
# Seasons
# [0, 0, 0, 0]
# returning C becuase no max
# A
# mechanical
# electrical
# conducting
# generator
# [1505664, 1503637, 1505475, 1503641]
# magnetic
# gravitational
# steel
# sphere
# [134, 0, 6, 0]
# B
# substances
# comparing
# different
# following
# [521781, 466612, 521780, 521789]
# thermometers
# balances
# thermometers
# sticks
# [0, 0, 0, 0]
# returning C becuase no max
# A
# organized
# material
# genetic
# humans
# [954267, 930604, 930603, 930606]
# 23
# 23
# 46
# 32
# [0, 0, 0, 0]
# returning C becuase no max
# B
# electromagnetic
# students
# spectrum
# students
# [1398462, 1398442, 1515391, 1398442]
# charts
# organize
# properties
# encouraged
# [0, 0, 0, 0]
# returning C becuase no max
# C
# characteristic
# Temperature
# temperature
# inversions
# [1458702, 317349, 317371, 317350]
# Inversions
# Inversions
# Inversions
# Inversions
# [0, 0, 0, 0]
# returning C becuase no max
# D
# effectiveness
# antibiotics
# explains
# period
# [1328124, 905431, 929549, 929433]
# Antibiotics
# Antibiotics
# Antibiotics
# Antibiotics
# [0, 0, 0, 0]
# returning C becuase no max
# C
# instructions
# generation
# contain
# passage
# [390625, 390629, 669239, 1041891]
# membrane
# Golgi
# chromosomes
# endoplasmic
# [4, 0, 4, 0]
# returning C becuase no max
# B
# measurements
# measurements
# measurements
# different
# [1260290, 1260290, 1260290, 437562]
# 120
# ms
# ms
# seconds
# [0, 0, 0, 0]
# returning C becuase no max
# A
# statement
# correctly
# applied
# liquid
# [1414850, 1530155, 1414558, 1415445]
# Atoms
# Atoms
# Atoms
# bump
# [0, 0, 0, 0]
# returning C becuase no max
# A
# Lystrosaurus
# distributed
# Antarctica
# following
# [263835, 770197, 263863, 265026]
# geographically
# Lystrosaurus
# Lystrosaurus
# India
# [0, 2, 2, 2]
# returning C becuase no max
# B
# conditions
# conditions
# atmosphere
# greenhouse
# [328239, 328239, 763802, 321036]
# denser
# cooler
# wetter
# cloudier
# [2, 6, 0, 0]
# C
# agricultural
# situations
# pesticide
# different
# [219403, 1335482, 219334, 219323]
# analyze
# pesticide
# validate
# pesticide
# [0, 7, 0, 7]
# returning C becuase no max
# C
# velocity
# objects
# object
# moving
# [566294, 580895, 566530, 565296]
# direction
# distance
# speed
# distance
# [90, 30, 133, 30]
# C
# belowStudent
# returning C becuase of BIG PROBLEM
# C
# evaporates
# atmosphere
# molecules
# molecules
# [1262461, 583554, 317173, 317173]
# reduced
# increased
# reduced
# increased
# [0, 0, 0, 0]
# returning C becuase no max
# C
# differentiation
# differentiate
# environment
# Scientists
# [810579, 810582, 810283, 93765]
# became
# became
# became
# became
# [0, 0, 0, 0]
# returning C becuase no max
# D
# molecular
# correct
# central
# biology
# [1066007, 733826, 729881, 1066008]
# RNA
# RNA
# RNA
# RNA
# [177, 177, 177, 177]
# returning C becuase no max
# C
# greatest
# negative
# survival
# species
# [102168, 102013, 861731, 102171]
# consumer
# decrease
# habitat
# producers
# [0, 1, 0, 0]
# A
# compounds
# following
# covalent
# reasons
# [513913, 513918, 517667, 803266]
# shell
# liquids
# involved
# neutrons
# [0, 1, 0, 0]
# 100301
#
#
#
#
#
# C
# generally
# naturally
# naturally
# equator
# [553862, 553854, 553854, 1368441]
# Indian
# Africa
# Pole
# Tropic
# [0, 0, 0, 0]
# returning C becuase no max
# B
# Eventually
# different
# direction
# important
# [928122, 564022, 564025, 564028]
# balance
# friction
# gravity
# size
# [0, 0, 0, 6]
# D
# following
# outermost
# planets
# planets
# [1445894, 1141167, 1445871, 1445871]
# little
# too
# surfaces
# surfaces
# [0, 1, 0, 0]
# C
# evolutionary
# reproduction
# reproduction
# Prokaryotes
# [795091, 784243, 784243, 784250]
# viral
# mitotic
# asexual
# sexual
# [0, 0, 15, 7]
# C
# electricity
# returning C becuase of BIG PROBLEM
# A
# transporting
# responsible
# structure
# modifying
# [684791, 684851, 674224, 361006]
# Golgi
# nucleus
# lysosome
# ribosome
# [0, 6, 0, 0]
# C
# conditions
# comparison
# competing
# batteries
# [1319220, 1319038, 448156, 1291850]
# twice
# contains
# stores
# destroys
# [0, 1, 0, 0]
# D
# located
# system
# galaxy
# solar
# [434383, 930510, 930508, 930509]
# middle
# underneath
# outside
# edge
# [1, 0, 2, 3]
# D
# transformed
# collision
# collide
# kinetic
# [1457861, 1277489, 1277251, 1277482]
# electrical
# electromagnetic
# magnetic
# sound
# [0, 0, 0, 0]
# returning C becuase no max
# B
# relationship
# circulatory
# important
# Arteries
# [849797, 145359, 145446, 145516]
# exchange
# nutrients
# independently
# relay
# [0, 0, 0, 0]
# returning C becuase no max
# A
# statement
# Students
# students
# watched
# [1414850, 1414918, 1414640, 1128707]
# inference
# predictions
# prediction
# inference
# [0, 0, 0, 0]
# returning C becuase no max
# C
# resources
# depleted
# likely
# Which
# [662321, 777534, 662285, 662281]
# Wind
# Solar
# Fossil
# Water
# [0, 3, 0, 10]
# A
# pregnancy
# placenta
# After
# birth
# [854054, 854056, 1056673, 185984]
# mother
# uterus
# pregnancy
# umbilicus
# [30, 32, 10, 0]
# A
# investigations
# supplements
# scientists
# conducted
# [919648, 918610, 919695, 920115]
# profit
# Garlic
# unreliable
# garlic
# [0, 0, 0, 0]
# returning C becuase no max
# A
# environment
# Estuaries
# particles
# mangrove
# [766697, 766644, 766944, 766125]
# decrease
# established
# Populations
# reduced
# [2, 3, 0, 0]
# D
# nucleotide
# following
# molecule
# Which
# [540999, 516756, 541004, 516753]
# oxygen
# glucose
# uracil
# adenine
# [44, 8, 2, 4]
# C
# projection
# classified
# vertebral
# between
# [960059, 837796, 837835, 837985]
# ballandsocket
# hinge
# pivot
# sliding
# [0, 0, 0, 0]
# returning C becuase no max
# B
# substances
# developing
# placenta
# across
# [902132, 120515, 120522, 902133]
# nutrients
# dioxide
# oxygen
# umbilicus
# [14, 4, 4, 0]
# D
# conditions
# following
# chicken
# running
# [1211538, 1211560, 173043, 1225207]
# chicken
# chicken
# chicken
# None
# [1, 1, 1, 0]
# returning C becuase no max
# B
# conditions
# following
# humidity
# humidity
# [346747, 478179, 346751, 346751]
# barometer
# psychrometer
# thermometer
# anemometer
# [3, 0, 3, 3]
# returning C becuase no max
# C
# horizontally
# sitting
# because
# starts
# [1359213, 140825, 1359282, 1359203]
# balanced
# frictional
# unbalanced
# exerted
# [0, 0, 3, 0]
# D
# temperatures
# hydrosphere
# statement
# explains
# [475807, 204348, 475611, 929549]
# Earthquake
# Mountain
# Rock
# Evaporation
# [0, 0, 0, 4]
# B
# naturally
# replenish
# Nitrogen
# nutrient
# [762217, 765869, 763400, 214082]
# enhanced
# fertilizer
# fix
# crop
# [0, 2, 2, 0]
# returning C becuase no max
# B
# different
# organisms
# evolved
# number
# [670769, 55768, 55769, 670767]
# Precambrian
# Paleozoic
# Cambrian
# Mesozoic
# [0, 0, 4, 0]
# D
# transported
# containing
# flowering
# structure
# [939527, 834834, 834751, 834821]
# nectar
# chlorophyll
# glucose
# pollen
# [3, 0, 0, 12]
# C
# population
# scientist
# collected
# scientist
# [442964, 263556, 263575, 263556]
# table
# pie
# graph
# scatterplot
# [1, 0, 0, 0]
# C
# specialized
# following
# allows
# become
# [825966, 1159209, 826001, 825965]
# location
# function
# patterns
# combinations
# [1, 1, 0, 0]
# returning C becuase no max
# C
# difference
# household
# different
# members
# [1047488, 651135, 1047474, 1047531]
# makeup
# behavioral
# genetics
# habitat
# [0, 0, 9, 0]
# D
# environmental
# Gasoline
# produced
# gasoline
# [1113499, 400349, 400618, 400527]
# erosion
# pollution
# wildlife
# warming
# [0, 11, 0, 6]
# A
# continental
# because
# floats
# mantle
# [287295, 287284, 258728, 287289]
# mantle
# material
# element
# mantle
# [33, 4, 0, 33]
# returning C becuase no max
# A
# patterns
# weather
# source
# energy
# [206275, 328394, 328347, 328334]
# Sun
# oceans
# Moon
# mountains
# [15, 1, 0, 0]
# B
# sidewalk
# because
# placed
# block
# [1436628, 566256, 1436675, 1436673]
# sidewalk
# sidewalk
# sidewalk
# sidewalk
# [7, 7, 7, 7]
# returning C becuase no max
# B
# earthquake
# passes
# mantle
# crust
# [278533, 294519, 268201, 268272]
# reverses
# speed
# increases
# stops
# [0, 0, 0, 0]
# returning C becuase no max
# B
# population
# variation
# species
# genetic
# [1081119, 925823, 1081117, 1081120]
# extinct
# extinct
# effected
# effected
# [1, 1, 0, 0]
# returning C becuase no max
# C
# highest
# would
# tides
# occur
# [309081, 279466, 309087, 309075]
# sunrise
# sunset
# full
# moon
# [0, 0, 3, 6]
# C
# appropriate
# recording
# classroom
# typical
# [1216735, 1215853, 162814, 1184408]
# gram
# kilogram
# meter
# kilometer
# [0, 0, 0, 0]
# returning C becuase no max
# D
# continuously
# atmosphere
# nonliving
# available
# [201094, 207996, 201136, 201080]
# fuels
# layering
# photosynthesis
# fires
# [7, 0, 11, 0]
# A
# ecosystem
# decompose
# benefit
# leaves
# [759945, 797764, 928259, 759979]
# Nutrients
# Soil
# absorbed
# Soil
# [0, 0, 3, 0]
# B
# organization
# increasing
# complexity
# following
# [1164575, 1164553, 930591, 1164452]
# shoot
# shoot
# shoot
# shoot
# [3, 3, 3, 3]
# returning C becuase no max
# B
# combination
# microscope
# underneath
# scientist
# [569726, 932200, 1313022, 932095]
# interaction
# weathering
# deposition
# abrasion
# [0, 0, 0, 0]
# returning C becuase no max
# C
# contributes
# following
# variation
# meiosis
# [1027404, 710795, 710918, 710855]
# pairing
# creation
# segregation
# separation
# [2, 0, 1, 0]
# C
# determine
# squirrels
# ecosystem
# forest
# [384860, 121051, 384800, 384796]
# squirrels
# squirrel
# squirrels
# articles
# [1, 0, 1, 0]
# returning C becuase no max
# C
# approximately
# temperature
# temperature
# increased
# [1389173, 1129289, 1129289, 1129291]
# levels
# ozone
# levels
# nitrogen
# [0, 0, 0, 0]
# returning C becuase no max
# A
# information
# hereditary
# necessary
# contain
# [950398, 950397, 1048699, 950396]
# regulating
# predicting
# creating
# producing
# [0, 0, 0, 0]
# returning C becuase no max
# B
# endangering
# returning C becuase of BIG PROBLEM
# B
# constantly
# returning C becuase of BIG PROBLEM
# B
# photovoltaic
# electricity
# renewable
# resource
# [403503, 221791, 221783, 221784]
# hydrothermal
# solar
# geothermal
# nuclear
# [0, 26, 0, 18]
# B
# atmosphere
# eruption
# directly
# transfer
# [286816, 286862, 286931, 414533]
# ground
# Sun
# animals
# animals
# [3, 48, 0, 0]
# D
# investigation
# identically
# hypothesis
# identical
# [914721, 913164, 914702, 914815]
# windows
# Different
# windows
# sizes
# [0, 0, 0, 0]
# returning C becuase no max
# D
# hurricanes
# possible
# Which
# these
# [358977, 724727, 724716, 724719]
# depth
# clarity
# salinity
# temperature
# [0, 0, 0, 0]
# returning C becuase no max
# B
# responsible
# population
# pesticides
# pesticide
# [729620, 51160, 51129, 51134]
# divergent
# selection
# bottleneck
# selective
# [0, 18, 0, 0]
# A
# appropriate
# interested
# experiment
# hypothesis
# [453576, 908164, 908320, 908331]
# oak
# oak
# transpire
# transpire
# [0, 0, 0, 0]
# returning C becuase no max
# B
# expressing
# Hydrogen
# chemical
# reaction
# [1456881, 526327, 1279450, 526321]
# write
# write
# rearrangement
# procedure
# [2, 2, 0, 0]
# returning C becuase no max
# A
# determined
# property
# neutrons
# element
# [1508360, 1513789, 1508383, 1508392]
# atomic
# radius
# electrical
# electrical
# [90, 0, 3, 3]
# D
# identified
# subatomic
# particles
# number
# [486052, 482136, 482137, 482140]
# neutrons
# electrons
# nuclei
# protons
# [42, 74, 6, 77]
# C
# Polymers
# made
# from
# are
# [1341470, 970891, 688374, 912061]
# macromolecules
# monosaccharides
# monomers
# proteins
# [1, 0, 7, 20]
# A
# reproduction
# offspring
# receives
# sexual
# [1021707, 710784, 27697, 710786]
# parent
# sibling
# itself
# offspring
# [68, 0, 0, 42]
# B
# relationships
# mutualistic
# organisms
# among
# [799622, 799621, 58634, 929199]
# ignore
# cooperate
# prey
# compete
# [0, 0, 2, 2]
# returning C becuase no max
# C
# statement
# describes
# climate
# Nevada
# [775098, 375822, 376063, 375886]
# dropped
# Wind
# Humidity
# week
# [0, 0, 0, 0]
# returning C becuase no max
# D
# Infectious
# diseases
# caused
# are
# [172661, 172662, 11291, 170464]
# allergies
# deficiencies
# spills
# microorganisms
# [0, 0, 0, 0]
# returning C becuase no max
# B
# located
# Where
# most
# mass
# [286069, 286071, 286073, 1145063]
# protons
# nucleus
# neutrons
# electrons
# [9, 38, 7, 13]
# A
# features
# returning C becuase of BIG PROBLEM
# D
# ecosystem
# changes
# single
# Which
# [213912, 41801, 595363, 595344]
# drought
# succession
# decomposition
# wildfire
# [0, 0, 0, 0]
# returning C becuase no max
# B
# crystalline
# identifies
# solid
# What
# [1237128, 315408, 1237129, 1237125]
# random
# repeating
# slide
# slide
# [0, 3, 0, 0]
# C
# considered
# converts
# glycogen
# function
# [9746, 1011281, 1011245, 1011129]
# transforms
# liver
# conversion
# liver
# [0, 3, 7, 3]
# D
# characteristics
# returning C becuase of BIG PROBLEM
# B
# specialized
# functions
# infection
# following
# [901378, 873644, 873673, 901177]
# red
# white
# muscle
# neuron
# [0, 0, 8, 0]
# A
# properties
# locations
# periodic
# chemical
# [1164349, 1160288, 1164342, 1164563]
# beryllium
# potassium
# titanium
# yttrium
# [1, 0, 0, 0]
# C
# information
# returning C becuase of BIG PROBLEM
# B
# processes
# smallest
# perform
# plant
# [774272, 774237, 947279, 774248]
# leaf
# cell
# tissue
# root
# [0, 43, 0, 0]
# B
# illustrates
# returning C becuase of BIG PROBLEM
# B
# continental
# difference
# between
# oceanic
# [272703, 272706, 270265, 272696]
# chiefly
# dense
# older
# continually
# [0, 0, 1, 0]
# C
# determined
# determined
# difference
# statement
# [1201593, 1201593, 1201597, 1513566]
# converted
# melted
# denser
# dense
# [0, 0, 0, 1]
# B
# measuring
# distances
# Neptune
# logical
# [1477555, 1482560, 1115480, 1482613]
# mile
# astronomical
# year
# kilometer
# [0, 0, 0, 0]
# returning C becuase no max
# C
# characteristic
# following
# spiral
# galaxy
# [540613, 540788, 540692, 930508]
# spherical
# armlike
# old
# halo
# [0, 0, 4, 0]
# B
# conditions
# natural
# fossil
# formed
# [399330, 534504, 399281, 534508]
# low
# high
# low
# low
# [4, 6, 4, 4]
# C
# observation
# conclusion
# different
# student
# [439797, 640349, 640336, 439687]
# exciting
# profile
# profile
# layers
# [1, 0, 0, 0]
# D
# equilibrium
# maintains
# mechanism
# messages
# [1284870, 938895, 1283098, 938968]
# liver
# blood
# fat
# pancreas
# [0, 11, 0, 0]
# B
# occasionally
# transferred
# convection
# following
# [1490452, 608876, 608901, 608326]
# pan
# soup
# spoon
# burner
# [0, 0, 1, 0]
# D
# designing
# statement
# accurate
# possible
# [1423917, 911759, 911117, 914129]
# measured
# Uranus
# belt
# Saturn
# [5, 0, 0, 0]
# D
# meteorologists
# television
# understand
# different
# [229824, 79420, 79241, 79328]
# reports
# meteorologists
# checking
# impact
# [0, 1, 0, 1]
# returning C becuase no max
# D
# following
# students
# accurate
# average
# [1414582, 1414640, 1445338, 1414696]
# Marcy
# Marcy
# Marcy
# Marcy
# [0, 0, 0, 0]
# returning C becuase no max
# B
# underwater
# because
# easier
# large
# [281154, 884484, 884462, 455713]
# buoyant
# buoyant
# underwater
# underwater
# [0, 0, 2, 2]
# returning C becuase no max
# A
# temperature
# increasing
# atmosphere
# continued
# [316474, 316477, 316492, 740417]
# reservoir
# Plant
# salinity
# Ocean
# [0, 0, 0, 0]
# returning C becuase no max
# D
# through
# except
# Sound
# waves
# [192654, 1482183, 192651, 192652]
# air
# steel
# water
# vacuum
# [3, 3, 4, 0]
# B
# concentration
# organisms
# activity
# producer
# [204160, 204963, 204668, 204883]
# nitrogen
# oxygen
# vapor
# dioxide
# [2, 21, 0, 22]
# D
# following
# greatest
# travels
# through
# [647711, 1328182, 647699, 647700]
# medium
# frequency
# amplitude
# proximity
# [0, 0, 0, 0]
# ...
# chemical
# [925062, 214373, 207803, 214372]
# producer
# consumer
# parasite
# decomposer
# [0, 1, 0, 0]
# A
# MidAtlantic
# returning C becuase of BIG PROBLEM
# C
# limestone
# indicates
# shows
# layer
# [375096, 375103, 237601, 375052]
# shale
# deposition
# deposition
# deposited
# [9, 0, 0, 9]
# returning C becuase no max
# D
# containing
# substances
# insoluble
# dissolved
# [978215, 978196, 1289736, 978195]
# Neither
# concentrate
# concentrate
# concentrate
# [0, 0, 0, 0]
# returning C becuase no max
# C
# environmental
# extinction
# variations
# Variations
# [774944, 775150, 774680, 379083]
# pressures
# reproduction
# random
# selection
# [0, 0, 1, 5]
# D
# following
# estimate
# typical
# number
# [1408923, 1384736, 1189215, 1408918]
# tens
# hundreds
# thousands
# billions
# [0, 0, 0, 0]
# returning C becuase no max
# A
# adaptations
# conserve
# mammals
# winter
# [395529, 395548, 851090, 395479]
# running
# hibernating
# huddling
# thicker
# [0, 0, 0, 0]
# returning C becuase no max
# A
# observation
# astronomer
# statement
# studying
# [1116770, 1519461, 1116758, 1116830]
# Star
# Star
# Suns
# Suns
# [0, 0, 0, 0]
# returning C becuase no max
# C
# advantage
# returning C becuase of BIG PROBLEM
# B
# Geologists
# conditions
# evidence
# changes
# [257655, 916505, 916492, 407458]
# younger
# younger
# younger
# younger
# [0, 0, 0, 0]
# returning C becuase no max
# C
# underground
# evidence
# exposed
# surface
# [292087, 390405, 292095, 292098]
# melted
# faults
# weathered
# folded
# [0, 0, 0, 0]
# returning C becuase no max
# A
# subsystems
# returning C becuase of BIG PROBLEM
# D
# information
# synthesize
# substance
# correctly
# [941350, 941266, 941570, 1069003]
# ATP
# mRNA
# tRNA
# DNA
# [55, 17, 0, 113]
# B
# pollution
# resource
# causes
# Which
# [403845, 215007, 778401, 277262]
# solar
# coal
# wind
# water
# [27, 2, 32, 97]
# C
# rainfall
# rainfall
# average
# Nevada
# [201766, 201766, 201764, 230747]
# elevations
# equator
# moisture
# great
# [0, 0, 0, 4]
# C
# endothermic
# endothermic
# observed
# reaction
# [528389, 528389, 1294017, 528390]
# reversible
# repeated
# requires
# released
# [1, 0, 0, 32]
# D
# geographic
# obstacle
# condense
# causes
# [1499463, 360581, 373230, 360587]
# forests
# oceans
# prairies
# mountains
# [0, 8, 0, 5]
# D
# tectonics
# property
# confirm
# helped
# [227104, 229370, 1140045, 1138756]
# weathered
# influences
# scrapes
# Earths
# [0, 0, 0, 0]
# returning C becuase no max
# B
# fertilization
# statement
# correctly
# explains
# [1029810, 911201, 911197, 910980]
# transcribed
# Male
# replicated
# counterparts
# [0, 0, 0, 0]
# returning C becuase no max
# D
# refrigerator
# returning C becuase of BIG PROBLEM
# C
# following
# greatest
# density
# layers
# [931190, 316127, 1523246, 1523222]
# crust
# mantle
# inner
# core
# [0, 0, 0, 27]
# B
# inflexible
# inflexible
# difficulty
# becomes
# [1453032, 1453032, 1427016, 1451178]
# allowing
# focusing
# converting
# seeing
# [0, 0, 0, 0]
# returning C becuase no max
# B
# atoms
# soda
# The
# can
# [1210068, 349315, 1340300, 1210066]
# locked
# loosely
# frequently
# loosely
# [0, 0, 2, 0]
# C
# surroundings
# information
# organelles
# surrounds
# [956296, 952730, 952813, 952778]
# endocrine
# skeletal
# integumentary
# lymphatic
# [0, 0, 0, 0]
# returning C becuase no max
# A
# evidence
# chemical
# reaction
# Which
# [531890, 520898, 520899, 520900]
# magnesium
# evaporation
# fizzing
# bulb
# [0, 0, 0, 0]
# returning C becuase no max
# B
# interactions
# illustrated
# boiling
# minutes
# [1459868, 1203389, 1459833, 1459824]
# low
# low
# insulator
# loses
# [0, 0, 0, 0]
# returning C becuase no max
# D
# relationship
# hibernation
# hibernate
# resources
# [823341, 823026, 823017, 84551]
# Hibernation
# Hibernation
# Hibernation
# Hibernation
# [8, 8, 8, 8]
# returning C becuase no max
# D
# grandfather
# grandfather
# sneezing
# visited
# [1384142, 1384142, 882720, 747871]
# circulatory
# excretory
# digestive
# immune
# [2, 0, 11, 0]
# A
# consequence
# tolerant
# tolerant
# affected
# [1081910, 1103247, 1103247, 1104746]
# mixing
# clearcutting
# farming
# thinning
# [0, 0, 0, 0]
# returning C becuase no max
# B
# relationship
# identifies
# statement
# correctly
# [911063, 1079401, 911201, 911197]
# depends
# Gravity
# depends
# Magnetic
# [0, 0, 0, 0]
# returning C becuase no max
# B
# geologists
# returning C becuase of BIG PROBLEM
# 102401
#
#
#
#
#
# A
# Millions
# pandemic
# people
# living
# [345582, 789983, 345584, 789995]
# contagious
# fatal
# Yes
# Yes
# [4, 0, 0, 0]
# C
# respiration
# following
# cellular
# which
# [152715, 1004639, 152714, 152716]
# plant
# animal
# animal
# nor
# [0, 0, 0, 0]
# returning C becuase no max
# D
# Bacteria
# illness
# humans
# cause
# [59950, 683775, 683777, 683774]
# altering
# weakening
# causing
# toxins
# [0, 0, 0, 0]
# returning C becuase no max
# B
# consideration
# emigration
# population
# ecosystem
# [121068, 195822, 195834, 196096]
# increase
# decrease
# population
# None
# [11, 5, 217, 0]
# D
# received
# measure
# amount
# light
# [1324739, 463130, 463142, 463112]
# parallax
# redshift
# absolute
# apparent
# [0, 0, 0, 0]
# returning C becuase no max
# D
# multicellular
# organisms
# comprised
# tissues
# [926197, 926198, 11711, 926208]
# organ
# organs
# organelles
# cells
# [6, 3, 4, 94]
# B
# ecosystems
# organisms
# Which
# form
# [759561, 683592, 683593, 683590]
# scavengers
# producers
# consumers
# decomposers
# [3, 6, 4, 5]
# C
# elements
# Periodic
# Elements
# Reading
# [553002, 552994, 552998, 499279]
# reactivity
# decrease
# atomic
# number
# [0, 0, 20, 34]
# C
# cardboard
# utilized
# dispose
# grocery
# [411459, 1278874, 409927, 1281436]
# month
# dumped
# recycled
# dumpster
# [0, 0, 12, 0]
# C
# statement
# correctly
# describes
# daylight
# [909152, 911197, 909154, 927128]
# Earths
# Earths
# Earths
# Earths
# [0, 0, 0, 0]
# returning C becuase no max
# A
# throughout
# ecosystem
# damaging
# hunting
# [218356, 395797, 192792, 218547]
# alteration
# degradation
# modification
# reversal
# [0, 0, 0, 0]
# returning C becuase no max
# C
# geological
# scale
# What
# time
# [368978, 371172, 371173, 368979]
# prehistoric
# disarray
# Earths
# placement
# [0, 0, 0, 0]
# returning C becuase no max
# A
# reactions
# chemical
# product
# number
# [524311, 1181631, 1293032, 1181629]
# reactants
# reactants
# reactants
# reactants
# [21, 21, 21, 21]
# returning C becuase no max
# C
# coneshaped
# returning C becuase of BIG PROBLEM
# C
# temperatureWhich
# returning C becuase of BIG PROBLEM
# B
# possible
# express
# firefly
# plants
# [1102581, 1102964, 632620, 1102956]
# firefly
# Diverse
# fluorescent
# engineered
# [1, 0, 2, 10]
# D
# environment
# surviving
# species
# changes
# [749461, 735895, 749465, 749462]
# lives
# places
# produces
# variations
# [0, 3, 0, 15]
# B
# continents
# position
# moderate
# bodies
# [343115, 343201, 342027, 235244]
# sea
# nearby
# equator
# radiation
# [10, 1, 0, 0]
# B
# overpopulation
# aquarium
# bacteria
# danger
# [775538, 200876, 775007, 776137]
# decrease
# reduction
# supply
# removal
# [0, 0, 6, 0]
# C
# transport
# materials
# property
# through
# [19251, 966904, 468476, 19249]
# solidifies
# transparent
# dissolves
# compound
# [0, 0, 1, 3]
# B
# temperate
# following
# tropical
# survival
# [764956, 764880, 764958, 844681]
# requirements
# exploit
# interbreed
# emigrate
# [0, 0, 0, 0]
# returning C becuase no max
# D
# constructive
# destructive
# different
# movement
# [618605, 618607, 618641, 362936]
# convergent
# subduction
# transform
# divergent
# [0, 0, 0, 0]
# returning C becuase no max
# C
# increasing
# student
# soccer
# upward
# [568019, 1360605, 569120, 568003]
# kinetic
# thermal
# potential
# mechanical
# [0, 0, 0, 0]
# returning C becuase no max
# A
# throughout
# classified
# different
# transport
# [468357, 468368, 468377, 688424]
# tissue
# organ
# system
# organism
# [0, 0, 0, 0]
# returning C becuase no max
# C
# atmosphere
# condensed
# liquid
# clouds
# [941978, 477833, 941981, 941985]
# methane
# nitrogen
# vapor
# dioxide
# [0, 3, 38, 9]
# D
# sediments
# Which
# these
# occur
# [360176, 1484600, 1484638, 1484613]
# precipitation
# evaporation
# partial
# recrystallization
# [0, 0, 0, 0]
# returning C becuase no max
# B
# seismogram
# illustrate
# seismic
# types
# [282835, 230592, 283186, 284000]
# 1
# 3
# 4
# 10
# [0, 3, 3, 7]
# C
# molecules
# elements
# organic
# Atoms
# [934833, 934841, 934832, 440745]
# calcium
# magnesium
# oxygen
# silicon
# [0, 0, 28, 0]
# A
# Approximately
# possibly
# plants
# ground
# [1256430, 398874, 399079, 399113]
# 1000000
# 100000
# 10000
# 1000
# [0, 0, 0, 0]
# returning C becuase no max
# D
# scientists
# experiment
# multiple
# perform
# [589, 5462, 922041, 5460]
# variables
# complete
# expensive
# likelihood
# [0, 0, 1, 0]
# A
# following
# ecosystem
# continue
# Which
# [1424361, 851029, 1371982, 1371986]
# decomposers
# continue
# consumers
# consumers
# [0, 5, 0, 0]
# A
# investigation
# performed
# determine
# addition
# [914721, 2162, 914981, 2274]
# trial
# trials
# trials
# trial
# [0, 2, 2, 0]
# returning C becuase no max
# D
# approximately
# subatomic
# particles
# Which
# [1254714, 488162, 488163, 488161]
# neutrons
# protons
# nucleus
# neutrons
# [72, 114, 48, 72]
# B
# statement
# opinion
# Which
# is
# [1476865, 222671, 1476864, 1476866]
# Physics
# subject
# Oceanography
# studies
# [0, 4, 0, 1]
# B
# thirdclass
# returning C becuase of BIG PROBLEM
# C
# following
# returning C becuase of BIG PROBLEM
# B
# chlorine
# combined
# chlorine
# between
# [1201870, 1275563, 1201870, 1201869]
# ionic
# elements
# covalent
# molecules
# [9, 13, 69, 39]
# C
# endoplasmic
# delivered
# reticulum
# modifies
# [688718, 688238, 688719, 688737]
# vacuole
# lysosome
# Golgi
# membrane
# [39, 0, 88, 32]
# C
# similarities
# evolutionary
# collectively
# Biologists
# [682785, 682795, 74842, 682331]
# technologies
# carbon14
# clocks
# timetables
# [0, 0, 0, 0]
# returning C becuase no max
# A
# reactants
# beginning
# chemical
# reaction
# [676555, 987125, 676235, 676236]
# rearranged
# appear
# disappear
# took
# [0, 0, 0, 1]
# C
# foodQuickgrow
# returning C becuase of BIG PROBLEM
# D
# reaction
# releases
# energy
# occurs
# [783284, 974610, 986358, 1124077]
# Golgi
# endoplasmic
# cytoplasmic
# mitochondrial
# [0, 0, 1, 2]
# D
# function
# vomiting
# reflex
# Which
# [871318, 1343814, 871658, 871265]
# rid
# expel
# empty
# toxic
# [0, 0, 0, 0]
# returning C becuase no max
# D
# sedimentary
# metamorphic
# classified
# Limestone
# [260721, 260928, 260788, 260707]
# fossils
# took
# times
# methods
# [6, 0, 0, 0]
# B
# developing
# credited
# vaccine
# rabies
# [383492, 382690, 382756, 788896]
# Salk
# Pasteur
# Jenner
# Koch
# [0, 0, 0, 0]
# returning C becuase no max
# B
# underwater
# objects
# locate
# Which
# [663563, 663564, 625025, 1511444]
# radar
# sonar
# telescope
# microscope
# [0, 8, 2, 4]
# B
# Scientists
# describe
# light
# term
# [285913, 915507, 915523, 915595]
# fast
# travels
# diameters
# galaxy
# [1, 0, 0, 0]
# C
# concentration
# toothpaste
# commercial
# toothpaste
# [530666, 1170105, 533768, 1170105]
# pleasant
# dentists
# hygiene
# sold
# [0, 0, 0, 0]
# returning C becuase no max
# D
# transfer
# removed
# region
# energy
# [1190255, 400924, 400889, 400945]
# Ozone
# Less
# lakes
# undergo
# [0, 0, 0, 0]
# returning C becuase no max
# B
# respiration
# molecules
# cellular
# results
# [704230, 1001441, 1001480, 1004148]
# growth
# release
# activity
# production
# [0, 8, 0, 2]
# D
# throughout
# horizontal
# training
# marathon
# [1043136, 1039512, 1043145, 865877]
# units
# units
# units
# units
# [8, 8, 8, 8]
# returning C becuase no max
# C
# chemical
# compound
# Which
# is
# [920335, 933375, 1182308, 933376]
# aluminum
# carbonated
# chloride
# carbon14
# [4, 0, 3, 0]
# B
# occasionally
# difference
# centuries
# observed
# [1490452, 1491225, 950131, 950219]
# comet
# Comets
# comets
# meteoroids
# [0, 0, 0, 0]
# returning C becuase no max
# B
# circulatory
# bloodstream
# maximizes
# chemicals
# [178356, 879961, 813008, 879772]
# nervous
# digestive
# immune
# excretory
# [0, 2, 23, 0]
# C
# exploratory
# returning C becuase of BIG PROBLEM
# A
# bloodstream
# detected
# secretes
# reducing
# [861538, 860812, 860748, 862491]
# feedback
# acquired
# balanced
# symbiotic
# [24, 0, 0, 0]
# A
# bacterialike
# returning C becuase of BIG PROBLEM
# A
# communities
# returning C becuase of BIG PROBLEM
# B
# Astronomical
# astronomical
# following
# millions
# [1115499, 1407469, 1408073, 1115752]
# gasses
# Earths
# cumulative
# eruptions
# [0, 0, 0, 0]
# returning C becuase no max
# A
# organisms
# common
# liver
# cells
# [969308, 688568, 965061, 969305]
# set
# location
# humans
# cellular
# [0, 3, 0, 7]
# D
# reproduction
# information
# reproduce
# generates
# [6867, 6871, 1022454, 1326836]
# Population
# inevitable
# maximized
# Large
# [0, 0, 0, 0]
# returning C becuase no max
# C
# population
# unusually
# describes
# outbreak
# [725748, 725607, 722940, 789126]
# pandemic
# plague
# epidemic
# infection
# [4, 0, 6, 5]
# B
# construction
# regulations
# regulations
# established
# [408008, 920873, 920873, 922110]
# resorts
# minimize
# rights
# courses
# [0, 0, 5, 0]
# B
# pharmaceutical
# discomfort
# reasonable
# released
# [1111979, 1297617, 1102707, 1111223]
# discomfort
# lowered
# patients
# lowered
# [1, 0, 6, 0]
# C
# atomic
# mass
# atom
# The
# [1149957, 1149923, 1509052, 1147251]
# atomic
# group
# sum
# difference
# [148, 0, 5, 0]
# C
# mitochondrial
# mitochondria
# chemiosmotic
# transport
# [704792, 976383, 704798, 704794]
# ADP
# ATP
# protons
# neutrons
# [7, 131, 4, 0]
# B
# firecracker
# originally
# produces
# stored
# [1371435, 990569, 990510, 990526]
# nuclear
# chemical
# electrical
# mechanical
# [0, 55, 0, 0]
# C
# astronomical
# measurement
# distance
# measure
# [1407469, 1156530, 1156542, 1156540]
# stars
# galaxies
# planets
# systems
# [3, 0, 0, 0]
# A
# billions
# person
# within
# clear
# [433857, 919405, 434089, 433998]
# galaxy
# cluster
# system
# structure
# [142, 38, 40, 8]
# A
# northwestern
# Atlantic
# currents
# surface
# [231088, 310393, 310383, 310382]
# southwest
# reversal
# upwelling
# rapid
# [0, 0, 6, 0]
# B
# molecules
# organisms
# complex
# living
# [387412, 925856, 925859, 387415]
# dioxide
# fats
# carbohydrates
# nitrogen
# [2, 0, 0, 46]
# B
# physically
# different
# interior
# several
# [1046345, 813808, 813836, 813807]
# core
# crust
# asthenosphere
# atmosphere
# [0, 0, 0, 3]
# B
# building
# likely
# will
# most
# [285205, 48128, 1101059, 64217]
# prevent
# destroy
# swim
# consume
# [0, 0, 0, 1]
# B
# periodic
# elements
# together
# grouped
# [1163350, 517549, 517551, 672399]
# lighter
# shells
# excess
# react
# [0, 0, 0, 1]
# B
# statements
# Hemisphere
# following
# explains
# [482423, 1193929, 482422, 612198]
# tropics
# Northern
# Northern
# Northern
# [0, 0, 0, 0]
# returning C becuase no max
# D
# selectively
# particular
# organism
# example
# [691410, 738086, 738095, 738106]
# cats
# graze
# herds
# chickens
# [0, 0, 0, 0]
# returning C becuase no max
# B
# cylindrical
# cylindrical
# container
# sample
# [1511927, 1511927, 1512245, 1409223]
# solid
# either
# liquid
# either
# [1, 0, 5, 0]
# C
# irregular
# intervals
# southward
# replacing
# [868431, 893903, 1439035, 886908]
# hurricane
# tornado
# Niño
# Ana
# [0, 0, 0, 0]
# returning C becuase no max
# D
# seismographs
# seismographs
# earthquake
# different
# [268014, 268014, 268016, 282313]
# pull
# interaction
# origins
# media
# [0, 0, 0, 0]
# returning C becuase no max
# D
# following
# genotypes
# offspring
# contains
# [40938, 40932, 40935, 747294]
# HHqqTt
# HhQqTt
# Hhqqtt
# HhqqTt
# [0, 0, 0, 0]
# returning C becuase no max
# C
# Fertilization
# combination
# results
# cells
# [713045, 1024934, 1024925, 1024929]
# egg
# sperm
# sperm
# somatic
# [11, 9, 9, 0]
# C
# invention
# culture
# develop
# living
# [1108845, 124298, 124295, 124268]
# production
# conditioning
# insulated
# irrigation
# [1, 0, 0, 0]
# A
# hydrogen
# Nuclear
# Besides
# element
# [504555, 602913, 602886, 602920]
# helium
# nitrogen
# oxygen
# uranium
# [0, 4, 0, 21]
# C
# astronomical
# statements
# following
# defines
# [1150893, 915722, 912412, 912236]
# year
# bright
# average
# Earths
# [0, 0, 3, 0]
# D
# 200millionyearold
# returning C becuase of BIG PROBLEM
# B
# considered
# returning C becuase of BIG PROBLEM
# C
# contribute
# extinction
# organisms
# common
# [195757, 56794, 195746, 195717]
# rotation
# fertilizers
# destruction
# competing
# [0, 0, 0, 0]
# returning C becuase no max
# A
# characteristic
# hereditary
# taxonomic
# organisms
# [954784, 955038, 954967, 954812]
# bacteria
# fungi
# plants
# animals
# [16, 2, 6, 2]
# B
# producing
# females
# called
# begin
# [899285, 899125, 899122, 899133]
# maturity
# born
# engaging
# monthly
# [0, 12, 0, 12]
# returning C becuase no max
# C
# substances
# developing
# following
# placenta
# [120544, 120515, 8108, 120522]
# oxygen
# wastes
# blood
# nutrients
# [12, 3, 0, 6]
# C
# currents
# surface
# develop
# How
# [310486, 310485, 748364, 310483]
# friction
# saltwater
# wind
# deltas
# [0, 0, 21, 0]
# B
# influence
# greatest
# survival
# become
# [820702, 1203335, 820858, 820612]
# foxs
# foxs
# fox
# fox
# [0, 0, 0, 0]
# returning C becuase no max
# A
# following
# believed
# warming
# global
# [779586, 917990, 779556, 779555]
# atmospheric
# conditioner
# landfills
# overpopulation
# [0, 0, 0, 0]
# returning C becuase no max
# B
# abundance
# mineral
# surface
# depends
# [1522269, 408129, 408135, 363312]
# particular
# crust
# thicknesses
# exposure
# [2, 0, 0, 0]
# A
# environmental
# Because
# changes
# history
# [55795, 402627, 1075987, 735211]
# extinct
# evolved
# plantlike
# affected
# [8, 3, 0, 1]
# B
# electrical
# property
# element
# wiring
# [1117910, 1117878, 1117930, 1494679]
# insulator
# conductor
# malleable
# porous
# [0, 0, 0, 0]
# returning C becuase no max
# B
# reproduction
# specialized
# analogous
# following
# [743382, 743217, 29537, 743346]
# genes
# sperm
# testes
# eggs
# [1, 3, 0, 2]
# D
# Biodiversity
# altered
# can
# be
# [776447, 218037, 1020369, 1020370]
# unexpected
# fire
# flood
# All
# [0, 2, 0, 2]
# returning C becuase no max
# B
# respiration
# organisms
# molecules
# Cellular
# [1000844, 562304, 1000842, 1000843]
# products
# reactants
# waste
# gases
# [18, 9, 6, 7]
# D
# pharmaceutical
# investigation
# investigation
# conducting
# [1111979, 666521, 666521, 666611]
# medicines
# ailments
# medicine
# accurately
# [1, 0, 2, 0]

# %% [raw]
# # sample = pd.read_csv('../input/sample_submission.csv')
# sample['correctAnswer'] = data['guess']
# sample.to_csv('../output/word_cluster_00.csv', index=False)

# %%
data.head()
# Out:
#        id                                           question  \
# 0  102501  A meter is industry by developing a process of...
# 1  102502  Which part of directly involved in recycling t...
# 2  102503  Which of the seeds grow better in the light or...
# 3  102504  Which of the hermaphroditic This growing seaso...
# 4  102505  When marsupials following is not a transport o...
#
#                       answerA  \
# 0  cool foods during shipping
# 1                     panting
# 2             muscular system
# 3           coniferous forest
# 4                       heart
#
#                                              answerB  \
# 0                                               yard
# 1                                            urethra
# 2  keep one group in a light place and another in...
# 3                             no reproductive organs
# 4                                           glucagon
#
#                                          answerC                  answerD  \
# 0                                 nervous system            birds of prey
# 1                                      predators                    water
# 2                                skates and rays           nervous tissue
# 3  there is less water loss through small leaves                perennial
# 4                                        hatched  to protect vital organs
#
#                                              keyword  \
# 0  [developing, industry, examples, process, heat...
# 1  [reproduction, temperature, recycling, directl...
# 2       [framework, provides, better, organs, Which]
# 3    [hermaphroditic, growing, season, Which, think]
# 4  [marsupials, following, transport, response, f...
#
#                                                 qvec      akeyword  \
# 0  [-0.0076541421935, 0.0428126163781, -0.0093698...    [shipping]
# 1  [-0.00762585951015, 0.00861827973276, -0.01647...     [panting]
# 2  [-0.0406858625356, 0.000434694252908, 0.027284...    [muscular]
# 3  [-0.0035101480782, 0.0597439706326, -0.0213354...  [coniferous]
# 4  [0.00498434053734, 0.000841771054547, -0.01591...       [heart]
#
#          bkeyword     ckeyword     dkeyword  \
# 0          [yard]    [nervous]      [birds]
# 1       [urethra]  [predators]      [water]
# 2       [another]     [skates]    [nervous]
# 3  [reproductive]    [through]  [perennial]
# 4      [glucagon]    [hatched]    [protect]
#
#                                                aavec  \
# 0  [0.0599160343409, 0.123002231121, -0.045650314...
# 1  [0.0639518499374, 0.0659503489733, -0.02526669...
# 2  [0.0851534381509, 0.12938041985, 0.03531557321...
# 3  [0.0473578386009, 0.0444385223091, 0.017191544...
# 4  [-0.0549635440111, 0.0888696238399, 0.02337735...
#
#                                                bavec  \
# 0  [0.00865275319666, 0.0433680191636, 0.04642602...
# 1  [-0.0568876340985, 0.0671530738473, -0.1180525...
# 2  [0.119020909071, -0.0120366625488, 0.056220933...
# 3  [0.00988108664751, 0.0588776506484, -0.0523356...
# 4  [-0.0631601214409, -0.0484089106321, -0.010907...
#
#                                                cavec  \
# 0  [0.0429564490914, 0.00291655748151, -0.0250321...
# 1  [-0.0123091973364, 0.0607602931559, -0.1267585...
# 2  [-0.0518872700632, -0.0753730908036, 0.0167950...
# 3  [0.00783920008689, 0.0335110835731, -0.0832989...
# 4  [-0.0236770678312, 0.0858293697238, -0.0198295...
#
#                                                davec
# 0  [0.0218830313534, 0.0545616932213, -0.10153727...
# 1  [-0.0583994314075, 0.0527478717268, 0.04502407...
# 2  [0.0429564490914, 0.00291655748151, -0.0250321...
# 3  [0.0817415639758, 0.203823119402, 0.0391014851...
# 4  [-0.0634209290147, 0.0630781129003, -0.0521080...

# %%
sum(data.guess == data.correctAnswer)/len(data)
# Out:
# 0.30959999999999999
